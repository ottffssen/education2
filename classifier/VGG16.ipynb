# %%
from keras.applications.vgg16 import VGG16,preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
from IPython.core.display import Image, display
# Out:
# Using TensorFlow backend.

# %%
vgg16 = VGG16(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %%
vgg16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
def predict(img_file_path):
    display(Image(img_file_path, width=150, unconfined=True))
    img = image.load_img(img_file_path, target_size=(224,224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    
    preds = vgg16.predict(preprocess_input(x))
    
    top = 5
    results = decode_predictions(preds, top=top)[0]
    for result in results:
        print(result)

# %%
predict('./data/samples/red.jpg')
# Out:
# Downloading data from https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json
# (u'n03595614', u'jersey', 0.99747199)
# (u'n04370456', u'sweatshirt', 0.0011212359)
# (u'n04532106', u'vestment', 0.00080778077)
# (u'n03877472', u'pajama', 0.00015126253)
# (u'n02669723', u'academic_gown', 0.00010416436)

# %%
predict('./data/samples/black.jpg')
# Out:
# (u'n03595614', u'jersey', 0.9693206)
# (u'n04370456', u'sweatshirt', 0.024596805)
# (u'n04599235', u'wool', 0.0032470524)
# (u'n04525038', u'velvet', 0.00092665857)
# (u'n02669723', u'academic_gown', 0.000537363)

# %%
predict('./data/samples/black.jpg')
# Out:
# (u'n04286575', u'spotlight', 0.040934868)
# (u'n03666591', u'lighter', 0.040249627)
# (u'n03729826', u'matchstick', 0.032025188)
# (u'n03637318', u'lampshade', 0.031878222)
# (u'n02948072', u'candle', 0.028473539)

# %%
predict('./data/samples/red.jpg')
# Out:
# (u'n07892512', u'red_wine', 0.020503569)
# (u'n04548280', u'wall_clock', 0.020273501)
# (u'n04418357', u'theater_curtain', 0.019521039)
# (u'n03291819', u'envelope', 0.018660191)
# (u'n04525038', u'velvet', 0.017915327)

# %%
predict('./data/samples/red.jpg')
# Out:
# (u'n03595614', u'jersey', 0.99747199)
# (u'n04370456', u'sweatshirt', 0.0011212359)
# (u'n04532106', u'vestment', 0.00080778077)
# (u'n03877472', u'pajama', 0.00015126253)
# (u'n02669723', u'academic_gown', 0.00010416436)
